# %%
import sys
bak = sys.argv[:]         # guardar argv del kernel
sys.argv = ["crypto.py", "--binance"]  # simular llamado sin args

sys.argv = bak

# %%
import pandas as pd


dfs = pd.read_excel("crypto.xlsx", sheet_name=None)  # None = todas las hojas

# df.tail(50)        # últimas 50
# df.iloc[100:200]   # rango específico

# dfs es un diccionario: clave = nombre de hoja, valor = DataFrame
for nombre, df in dfs.items():
    print(f"--- {nombre} ---")
    cantidad = df.head(50)        # primeras 50
    display(cantidad)  # en Jupyter muestra tabla
# Out:
# --- BTC ---
#   Fecha de Compra Cripto  Cantidad  Precio Compra (USD)  Valor Actual (USD)  \
# 0      2022-08-20    BTC  0.004648                  100            21515.61
# 1      2025-07-15    BTC  0.002613                  310           118630.43
# 2      2025-07-15    BTC -0.002529                 -300           118630.43
# 3      2025-08-14    BTC -0.000169                  -20           118123.30
#
#         Wallet ¿Stakeado? (Sí/No)  Total Crypto  Total USD
# 0  bitcoin.com                 No           NaN        NaN
# 1         prex                 No           NaN        NaN
# 2  bitcoin.com                 No           NaN        NaN
# 3         prex                 No           NaN        NaN
# --- ETH ---
#   Fecha de Compra Cripto  Cantidad  Precio Compra (USD)  Valor Actual (USD)  \
# 0      2024-12-31    ETH  0.029759                  100             3360.38
# 1      2025-07-15    ETH  0.032628                  110             3371.35
# ...

# %%
import pandas as pd


dfs = pd.read_excel("crypto.xlsx", sheet_name=None)  # None = todas las hojas

# df.tail(50)        # últimas 50
# df.iloc[100:200]   # rango específico

# dfs es un diccionario: clave = nombre de hoja, valor = DataFrame
for nombre, df in dfs.items():
    print(f"--- {nombre} ---")
    cantidad = df.head(50)        # primeras 50
    display(cantidad)  # en Jupyter muestra tabla
# Out:
# --- BTC ---
# Empty DataFrame
# Columns: [Fecha de Compra, Cripto, Cantidad, Precio Compra (USD), Valor Actual (USD), Wallet, ¿Stakeado? (Sí/No), Total Crypto, Total USD]
# Index: []
# --- ETH ---
# Empty DataFrame
# Columns: [Fecha de Compra, Cripto, Cantidad, Precio Compra (USD), Valor Actual (USD), Wallet, ¿Stakeado? (Sí/No), Total Crypto, Total USD]
# Index: []
# --- SOL ---
# Empty DataFrame
# Columns: [Fecha de Compra, Cripto, Cantidad, Precio Compra (USD), Valor Actual (USD), Wallet, ¿Stakeado? (Sí/No), Total Crypto, Total USD]
# Index: []
# --- BCH ---
# Empty DataFrame
# Columns: [Fecha de Compra, Cripto, Cantidad, Precio Compra (USD), Valor Actual (USD), Wallet, ¿Stakeado? (Sí/No), Total Crypto, Total USD]
# Index: []
# --- USDT ---
# Empty DataFrame
# Columns: [Fecha de Compra, Cripto, Cantidad, Precio Compra (USD), Valor Actual (USD), Wallet, ¿Stakeado? (Sí/No), Total Crypto, Total USD]
# Index: []
# --- Binance Spot ---
#   Asset        Free  Locked       Total
# ...
